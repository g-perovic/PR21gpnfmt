# %% [markdown]
# # PODATKOVNO RUDARJENJE - PROJEKT
#
# ## TEHNIČNI PREGLEDI MOTORNIH VOZIL
#
# ### Avtorji
# Nejc Frank, Gašper Perovič, Matija Tomažič
# <br></br>
# ### 1. Predstavitev naše množice podatkov
#
# Množica podatkov nad katero bomo opravljali raziskave in ugotavljali kakšne vplive imajo določeni atributi na druge, smo našli na spletni strani www.podatki.gov.si. Na omenjeni spletni strani so različni statistični podatki zbrani iz Slovenije, kar je tudi razlog, da smo se odločili uporabljati te podatke oz. množico podatkov.
#
# Množica je sestavljena iz podatkov, ki opisujejo vozilo (znamka,tovarniška oznaka, vrsta goriva, prevoženi kilometri...) ter podatkov, ki nam povedo, če je vozilo tehnično dovršeno in kje opravlja tehnične preglede.
#
# Za to množico podatkov smo se odločili, ker se nam je zdela zanimiva za ugotvaljanje, opravljanja tehničnih pregledov glede na znamko, leto proizvodnje, vrsto goriva, pri koliko kilometrov različna vozila niso več tehnično brezhibna ipd.
#
# Pri izbiri množice smo bili pozorni tudi na to, da vsebuje dovolj podatkov za obdelavo saj nismo hoteli biti omejeni pri naših raziskavah.
#
# <br></br>
# ### 2. Manjšanje množice podatkov ter popravki
#
# Po odločitvi o izbiri podatkov smo pri uvozu podatkov naleteli na težavo, saj je bila množica podatkov prevelika. Zaradi zahteve po dovolj veliki množici se je izkazalo, da je bilo podatkov preveč za uvoz na git, zato smo množico skrajšali iz pogleda števila posameznih avtov ne pa iz pogleda števila podatkov posameznega vozila.
#
# <br></br>
# ### 3. Branje podatkov
#
# Množica podatkov, ki smo jo prenesli iz spletne strani je bila v obliki csv datoteke. V DataFrame smo jo uvozili preko knjižnice "PANDAS", da smo jo lahko v nadaljevanju klicali po stolpcih, ki smo jih uporabili za različne poizvedbe.
#
# Branje datoteke:
#
# ```python
# import pandas as pd
# podatki = pd.read_csv("Porocilo_o_uspesnosti_TP_1.csv", delimiter=";", low_memory=False)
# ```
#
# <br></br>
# ### 4. Opis atributov in vrednosti
#
# - Znamka - diskretni atribut
# - Tovarniška oznaka - diskretni atribut
# - Komercialna oznaka - diskretni atribut
# - Komercialni tip - diskretni atribut
# - Kategorija oznaka - diskretni atribut
# - Kategorija opis - diskretni atribut
# - Nadgradnja oznaka - diskretni atribut
# - Nadgradnja opis - diskretni atribut
# - Vrsta goriva - zvezni atribut
# - Datum prve registracije in nato v SLO - zvezna atributa
# - Prevoženi kilometri - zvezni atribut
# - Lastnik vozila (P ali F) - pravna ali fizična oseba - diskretni atribut
# - Tehnični pregled status - diskretni atribut
# - Veljavnost tehničnega pregleda od-do - zvezni atribut
# - Izvajalna enota - diskretni atribut
#
# <br></br>
# ### 5. Rezultati
#
#
# #### - Poizvedba, prikaže število motornih vozil glede na vrsto vozila, izpisano z stolpičnim diagramom.
#
# ![image](https://user-images.githubusercontent.com/64787664/168778494-1bdff1e4-593d-46ae-bcd4-baf3ee04606f.png)
#
# Ker je bilo število osebnih avtomobilov naprimerno večje kot vsi ostali rezultati smo zaradi preglednosti izločili podatke od osebnih vozilih in izpisali le vsa ostala motorna vozila.
#
# <br></br>
# #### - Poizvedba, ki prikazuje 10 izvajalnih enot, pri katerih je bil odstotek tehnično brezhibnih vozil največji.
#
#
# ![slika](https://user-images.githubusercontent.com/64787664/168562516-f919e0d7-83a7-4374-945e-04ec4e29b9b5.png)
#
# Iz tabele lahko razberemo, pri katerih upravljalih enotah se najbolj "splača" opravljati tehnični pregled avtomobila, če se malce pošalimo.
#
# <br></br>
# #### - Prikaz števila registriranih osebnih vozil po znamkah
#
# ![slika](https://user-images.githubusercontent.com/64787664/168558132-c6b2c5cd-683a-49d0-8be9-54c18472398c.png)
#
# Kot je iz grafa razvidno imamo največ osebnih vozil znamke Renault in nato Volkswagen. Za prvimi dvemi pa imamo še znamke Opel, Peugeot in Citroën. V grafu smo upoštevali samo znamke ki imajo vsaj 50 vnosov, ker imamo veliko znamk s pod 50-imi vnosi in bi težko razbrali podatke iz grafa.
#
# <br></br>
# #### - Odstotek brezhibno opravljenih Tehničnih pregledov osebnih avtomobilov po znamkah(Deset najbolj brezhibnih znamk osebnih avtomobilov)
#
#
#
# ![image](https://user-images.githubusercontent.com/64787664/163146975-d33b70fc-6fef-449c-83a1-7f08b21e80d3.png)
# Tabela prikazuje 10 najbolj breizhibnih znamk osebnih avtomobilov. Odstotek breizhibnosti pa je odstotek brizhibno opravljenih tehničnih pregledov vsake znamke. Upoštevali smo le znamke ki imajo vsaj 50 vnosov.
#
# <br></br>
# #### - Število tehničnih pregledov po mesecih
#
# ![image](https://user-images.githubusercontent.com/64787664/163156762-796dd467-2714-4426-92f6-76fed35f417c.png)
#
#
# Iz grafa vidimo, da se največ tehničnih pregledov opravlja marca in maja. S tega sklepamo, da je največ registracij opravljenih v teh dveh mesecih.
#
# <br></br>
# #### - Avtomobili z povprečno največ prevoženimi kilometri v dnevu (5 vozil z najboljšim povprečjam prevoženih kilometrov na dan)
#
#
#
# |ZNAMKA|DATUM PRVE REGISTRACIJE|DATUM PREGLEDA|PREVOZENI KILOMETRI|POVPREČNO KM NA DAN|
# |------|---------------------------|--------------|-------------------|-------------------|
# |SEAT|29.08.2020|26.08.2021|212577.0 5|587.22|
# |FIAT|13.11.2020|15.11.2021|152255.0|414.86|
# |TOYOTA|1.04.2019|29.03.2021|201574.0|276.88|
# |MERCEDES BENZ|5.10.2010|30.09.2021|992611.0|247.34|
# |BMW|1.03.2018|5.03.2021|265555.0|241.41|
#
# V zgornji tabeli lahko vidimo 5 avtomobilov z povprečno največ prevoženimi kilometri v enem dnevu  ter njihove pripadajoče prevožene kilometre. Vozilo, ki je zasedlo prvo mesto je "SEAT" z povprečnimi 587.22km na dan. Med podatki smo morali biti pozorni, saj so bili nekateri podatki nesmiselni (naprimer "OPEL ASTRA" z 19mio kilometri).
#
#
# <br></br>
# #### - Odstotek opravljenih tehničnih pregledov osebnih avtomobilov po desetletjih (datum prve registracije)
#
# ![image](https://user-images.githubusercontent.com/64787664/168559104-dc1071a6-aa28-4d55-87f9-0a5667d515e8.png)
#
# Graf prikazuje odstotek opravljenih (modra barva)  ter odstotek neopravljenih (oranžna barva) tehničnih pregledov po različnih desetletjih. To smo dosegli tako, da smo podatke najprej združili po desetletjih in nato računali odstotek opravljenih tehničnih pregledov. Desetletja v katerih je bilo registriranih premalo avtomobilov smo izločili.
#
# Prišli smo do ugotovitve, da so avtomobili registrirani v bolj zgodnjih desetletjih v povprečju bolj pogosto tehnično brezhibni, ker je bila po našem mnjenju izdelava le teh v preteklosti bolj kakovostna.
#
# <br></br>
# #### - Odstotek opravljenih tehničnih pregledov pri oldtimerjih v primerjavi z vsemi ostalimi avtomobili
#
# ![image](https://user-images.githubusercontent.com/64787664/168566444-8bc289f6-fa17-4c78-b208-d06bd347fa1a.png)
#
#
# Med oldtajmerje smo šteli avtomobile, ki so opravili prvi tehnični pregled pred več kot 30 leti.Med oldtajmerji smo pogledali odstotek brezhibno opravljenih tehničnih pregledov ter podatke primerjali z vsemi ostalimi avtomobili.
#
# Ugotovili smo, da v povprečju 10% več oldtajmerjev opravi tehnični pregled v primerjavi z novodobnimi avtomobili. Iz tega lahko sklepamo, da ljudje za oldtajmerje bolje skrbijo in zato posledično opravijo tehnični pregled bolj pogosto.
#
#
# <br></br>
# #### - Povprečno število prevoženih kilometrov, ko vozilo ne opravi več tehničnega pregleda petih najbolj popularnih znamk avtomobilov.
#
# |ZNAMKA|POVPREČNI KILOMETRI|
# |------|-------------------|
# |RENAULT|190213.985576|
# |VOLKSWAGEN|260323.919736|
# |OPEL|195921.192794|
# |CITROEN|204778.718830|
# |PEUGEOT|191290.674769|
#
# Pri tej poizvedbi nas je zanimalo, koliko kilometrov v popvrečju naredi avtomobil določene znamke, preden tehnično ni več brezhiben. Gledali pa smo 5 znamk avtomobilov, ki so najbolj popularne in posledično najbolj prodajane.
